# %%
# %matplotlib inline

# %%
import argparse
import glob

import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import datreant.core as dtr

# %%
b = dtr.discover('../../../solvers/solver_timing/Data/')

# %%
df = pd.DataFrame(b.categories.all)

# %%
for name, library in df.groupby("library"): 
    library = library.sort_values(by="numberOfElements")
    plt.loglog(library["numberOfElements"], library["elapsed"], label=name)
plt.legend(loc="upper left")
plt.xlabel("number of elements")
plt.ylabel("elapsed time / s")

# %%
b = dtr.discover('../../../solvers/solver_timing/memory/Data/')

# %%
df = pd.DataFrame(b.categories.all)

# %%
for name, library in df.groupby("library"): 
    library = library.sort_values(by="numberOfElements")
    plt.loglog(library["numberOfElements"], library["elapsed"], label=name)
plt.legend(loc="upper left")
plt.xlabel("number of elements")
plt.ylabel("elapsed time / s")

# %%
mprof = !which mprof
execfile(mprof[-1])
# Out:
# Usage: __main__.py <command> <options> <arguments>
#
# Available commands:
#
#     run      run a given command or python file
#     rm       remove a given file generated by mprof
#     clean    clean the current directory from files created by mprof
#     list     display existing profiles, with indices
#     plot     plot memory consumption generated by mprof run
#
# Type mprof <command> --help for usage help on a specific command.
# For example, mprof plot --help will list all plotting options.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /Users/guyer/anaconda/envs/condafipy/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2889: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
def parse_args(mprofile):
    parser = argparse.ArgumentParser()
    parser.add_argument("--output", help="directory to store results in")
    parser.add_argument("--numberOfElements", help="number of total cells in a Grid2D",
                        type=int, default=10000)
    parser.add_argument("--solver", help="solver class to use",
                        choices=("cg", "pcg", "cgs", "gmres", "lu"), default="cg")
    parser.add_argument("--sweeps", help="number of nonlinear sweeps to take",
                        type=int, default=10)
    parser.add_argument("--iterations", help="maximum number of linear iterations to take for each sweep",
                        type=int, default=1000)
    parser.add_argument("--tolerance", help="linear solver tolerance",
                        type=float, default=1e-10)
    parser.add_argument("--writeFiles", help="whether to write solution values and matrix to OUTPUT",
                        action='store_true')
    
    parser.add_argument("--pysparse", help="use PySparse solvers", dest="library",
                        action="store_const", const="pysparse")
    parser.add_argument("--trilinos", help="use PyTrilinos solvers", dest="library",
                        action="store_const", const="trilinos")
    parser.add_argument("--scipy", help="use SciPy solvers", dest="library",
                        action="store_const", const="scipy")
    parser.set_defaults(library="pysparse")

    print mprofile['cmd_line']
    return parser.parse_known_args(mprofile['cmd_line'])

# %%
df['mem_usage'] = np.NaN

# %%
args.__dict__
# Out:
# {'iterations': 1000,
#  'library': 'pysparse',
#  'numberOfElements': 10000,
#  'output': None,
#  'solver': 'cg',
#  'sweeps': 10,
#  'tolerance': 1e-10,
#  'writeFiles': False}

# %%
highwater = []

for f in glob.glob('../../../solvers/solver_timing/memory/mprofile_*.dat'):
    mprofile = read_mprofile_file(f)
    
    args, unknowns = parse_args(mprofile)
    args.__dict__['mem_usage'] = max(mprofile['mem_usage'])
    highwater.append(args.__dict__)
#    df[(df["library"] == args.library) 
#       & (df["solver"] == args.solver) 
#       & (df["numberOfElements"] == args.numberOfElements)]['mem_usage'] = max(mprofile['mem_usage'])

highwater
# Out:
# python /users/guyer/FiPy/fipy/examples/benchmarking/solvers/diffusion.py --trilinos --numberOfElements=100 --output Data/d94fbe7f-1517-4ab7-bbdf-c269401115f0 --sweeps 3
#
# python /users/guyer/FiPy/fipy/examples/benchmarking/solvers/diffusion.py --trilinos --numberOfElements=1000 --output Data/10f97a8e-c473-42ce-b260-c273b10ef7ae --sweeps 3
#
# python /users/guyer/FiPy/fipy/examples/benchmarking/solvers/diffusion.py --trilinos --numberOfElements=10000000 --output Data/e91f2378-4d33-4ee6-96e1-a82ef5aef967 --sweeps 3
#
# python /users/guyer/FiPy/fipy/examples/benchmarking/solvers/diffusion.py --scipy --numberOfElements=100 --output Data/f1853e58-269d-4862-ae10-d293dbbfa684 --sweeps 3
#
# python /users/guyer/FiPy/fipy/examples/benchmarking/solvers/diffusion.py --scipy --numberOfElements=1000000 --output Data/b7871336-2ccc-44cb-944d-a6c4d8eb02fd --sweeps 3
#
# python /users/guyer/FiPy/fipy/examples/benchmarking/solvers/diffusion.py --scipy --numberOfElements=10000 --output Data/277910c4-5c28-413c-87d7-6257dfda7055 --sweeps 3
#
# python /users/guyer/FiPy/fipy/examples/benchmarking/solvers/diffusion.py --pysparse --numberOfElements=1000 --output Data/50e332d4-761d-4ec4-977d-a4e73da63072 --sweeps 3
#
# python /users/guyer/FiPy/fipy/examples/benchmarking/solvers/diffusion.py --pysparse --numberOfElements=10000 --output Data/f7911aed-9081-44e2-b91c-1b81af7fdda9 --sweeps 3
#
# python /users/guyer/FiPy/fipy/examples/benchmarking/solvers/diffusion.py --pysparse --numberOfElements=10000000 --output Data/b966eaef-2105-486a-b4cb-5c5d558df8fc --sweeps 3
# [{'iterations': 1000,
#   'library': 'pysparse',
#   'mem_usage': 86.246094,
#   'numberOfElements': 10000,
#   'output': None,
#   'solver': 'cg',
#   'sweeps': 10,
#   'tolerance': 1e-10,
#   'writeFiles': False},
#  {'iterations': 1000,
#   'library': 'pysparse',
#   'mem_usage': 100.804688,
#   'numberOfElements': 10000,
#   'output': None,
#   'solver': 'cg',
#   'sweeps': 10,
#   'tolerance': 1e-10,
#   'writeFiles': False},
#  {'iterations': 1000,
#   'library': 'pysparse',
#   'mem_usage': 12352.59375,
#   'numberOfElements': 10000,
#   'output': None,
#   'solver': 'cg',
#   'sweeps': 10,
#   'tolerance': 1e-10,
#   'writeFiles': False},
#  {'iterations': 1000,
#   'library': 'pysparse',
#   'mem_usage': 54.277344,
#   'numberOfElements': 10000,
#   'output': None,
#   'solver': 'cg',
#   'sweeps': 10,
#   'tolerance': 1e-10,
#   'writeFiles': False},
#  {'iterations': 1000,
#   'library': 'pysparse',
#   'mem_usage': 10746.234375,
#   'numberOfElements': 10000,
#   'output': None,
#   'solver': 'cg',
#   'sweeps': 10,
#   'tolerance': 1e-10,
#   'writeFiles': False},
#  {'iterations': 1000,
#   'library': 'pysparse',
#   'mem_usage': 181.398438,
#   'numberOfElements': 10000,
#   'output': None,
#   'solver': 'cg',
#   'sweeps': 10,
#   'tolerance': 1e-10,
#   'writeFiles': False},
#  {'iterations': 1000,
#   'library': 'pysparse',
#   'mem_usage': 45.164062,
#   'numberOfElements': 10000,
#   'output': None,
#   'solver': 'cg',
#   'sweeps': 10,
#   'tolerance': 1e-10,
#   'writeFiles': False},
#  {'iterations': 1000,
#   'library': 'pysparse',
#   'mem_usage': 57.195312,
#   'numberOfElements': 10000,
#   'output': None,
#   'solver': 'cg',
#   'sweeps': 10,
#   'tolerance': 1e-10,
#   'writeFiles': False},
#  {'iterations': 1000,
#   'library': 'pysparse',
#   'mem_usage': 11271.007812,
#   'numberOfElements': 10000,
#   'output': None,
#   'solver': 'cg',
#   'sweeps': 10,
#   'tolerance': 1e-10,
#   'writeFiles': False}]

# %%
pd.DataFrame(highwater)
# Out:
#    iterations   library     mem_usage  numberOfElements output solver  sweeps  \
# 0        1000  pysparse     86.246094             10000   None     cg      10
# 1        1000  pysparse    100.804688             10000   None     cg      10
# 2        1000  pysparse  12352.593750             10000   None     cg      10
# 3        1000  pysparse     54.277344             10000   None     cg      10
# 4        1000  pysparse  10746.234375             10000   None     cg      10
# 5        1000  pysparse    181.398438             10000   None     cg      10
# 6        1000  pysparse     45.164062             10000   None     cg      10
# 7        1000  pysparse     57.195312             10000   None     cg      10
# 8        1000  pysparse  11271.007812             10000   None     cg      10
#
#       tolerance writeFiles
# 0  1.000000e-10      False
# 1  1.000000e-10      False
# 2  1.000000e-10      False
# 3  1.000000e-10      False
# 4  1.000000e-10      False
# 5  1.000000e-10      False
# 6  1.000000e-10      False
# 7  1.000000e-10      False
# 8  1.000000e-10      False

# %%
df[:5]
# Out:
#     elapsed  iterations   library  numberOfElements  processes  \
# 0  18406.32      1000.0  trilinos         1000000.0        1.0
# 1      0.45      1000.0     scipy             100.0        1.0
# 2      0.42      1000.0  trilinos             100.0        1.0
# 3  25033.30      1000.0     scipy         1000000.0        1.0
# 4   3983.78      1000.0     scipy          100000.0        1.0
#
#                                               script solver  \
# 0  /users/guyer/FiPy/fipy/examples/benchmarking/s...     cg
# 1  /users/guyer/FiPy/fipy/examples/benchmarking/s...     cg
# 2  /users/guyer/FiPy/fipy/examples/benchmarking/s...     cg
# 3  /users/guyer/FiPy/fipy/examples/benchmarking/s...     cg
# 4  /users/guyer/FiPy/fipy/examples/benchmarking/s...     cg
#
#    sweep 0 - iterations  sweep 1 - iterations  sweep 2 - iterations  \
# 0                1000.0                1000.0                1000.0
# 1                  10.0                  15.0                  16.0
# 2                  10.0                  15.0                  16.0
# 3                1000.0                1000.0                1000.0
# 4                 460.0                 793.0                 491.0
#
#    sweep 3 - iterations  sweep 4 - iterations  sweep 5 - iterations  \
# 0                1000.0                1000.0                1000.0
# 1                  17.0                  16.0                  17.0
# 2                  17.0                  16.0                  17.0
# 3                1000.0                1000.0                1000.0
# 4                 700.0                 529.0                 620.0
#
#    sweep 6 - iterations  sweep 7 - iterations  sweep 8 - iterations  \
# 0                1000.0                1000.0                1000.0
# 1                  16.0                  17.0                  17.0
# 2                  16.0                  17.0                  16.0
# 3                1000.0                1000.0                1000.0
# 4                 561.0                 589.0                 572.0
#
#    sweep 9 - iterations  sweeps     tolerance  mem_usage
# 0                1000.0    10.0  1.000000e-10        NaN
# 1                  16.0    10.0  1.000000e-10        NaN
# 2                  17.0    10.0  1.000000e-10        NaN
# 3                1000.0    10.0  1.000000e-10        NaN
# 4                 579.0    10.0  1.000000e-10        NaN

# %%
mprofile.keys()
# Out:
# ['cmd_line', 'timestamp', 'func_timestamp', 'mem_usage', 'filename']

# %%
max(mprofile['mem_usage'])
# Out:
# 86.246094

# %%
args
# Out:
# Namespace(iterations=1000, library='pysparse', numberOfElements=10000, output=None, solver='cg', sweeps=10, tolerance=1e-10, writeFiles=False)

# %%
# Out:
# ['../../../solvers/solver_timing/memory/mprofile_20170210154924.dat',
#  '../../../solvers/solver_timing/memory/mprofile_20170210154948.dat',
#  '../../../solvers/solver_timing/memory/mprofile_20170210154955.dat',
#  '../../../solvers/solver_timing/memory/mprofile_20170210155010.dat',
#  '../../../solvers/solver_timing/memory/mprofile_20170210155024.dat',
#  '../../../solvers/solver_timing/memory/mprofile_20170210155026.dat',
#  '../../../solvers/solver_timing/memory/mprofile_20170210155038.dat',
#  '../../../solvers/solver_timing/memory/mprofile_20170210155039.dat',
#  '../../../solvers/solver_timing/memory/mprofile_20170210155042.dat']
